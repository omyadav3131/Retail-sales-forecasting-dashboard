# %%
import pandas as pd
#load cleaned dataset
df = pd.read_csv("../data/processed/cleaned_data.csv")

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (8523, 13)
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.022911
# 4           NCD19         8.93          Low Fat         0.016164
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Store_Age
# 0  Supermarket Type1          3735.1380         14
# 1  Supermarket Type2           443.4228          4
# 2  Supermarket Type1          2097.2700         14
# 3      Grocery Store           732.3800         15
# 4  Supermarket Type1           994.7052         26

# %%
# Target variable
y = df['Item_Outlet_Sales']

#Features
x = df.drop('Item_Outlet_Sales',axis=1)

print("Feature Shape:",x.shape)
print("Target Shape:",y.shape)
# Out:
# Feature Shape: (8523, 12)
# Target Shape: (8523,)

# %%
x.select_dtypes(include='object').columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
x = x.drop (['Item_Identifier','Outlet_Identifier'], axis=1)

print("New Feature Shape:",x.shape)
# Out:
# New Feature Shape: (8523, 10)

# %%
x = pd.get_dummies(x, drop_first=True)

print(" Encouded Feature Shape: ",x.shape)
x.head()
# Out:
#  Encouded Feature Shape:  (8523, 28)
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.022911  182.0950                       1998
# 4         8.93         0.016164   53.8614                       1987
#
#    Store_Age  Item_Fat_Content_Regular  Item_Type_Breads  Item_Type_Breakfast  \
# 0         14                     False             False                False
# 1          4                      True             False                False
# 2         14                     False             False                False
# 3         15                      True             False                False
# 4         26                     False             False                False
#
#    Item_Type_Canned  Item_Type_Dairy  ...  Item_Type_Snack Foods  \
# 0             False             True  ...                  False
# 1             False            False  ...                  False
# 2             False            False  ...                  False
# 3             False            False  ...                  False
# 4             False            False  ...                  False
#
#    Item_Type_Soft Drinks  Item_Type_Starchy Foods  Outlet_Size_Medium  \
# 0                  False                    False                True
# 1                   True                    False                True
# 2                  False                    False                True
# 3                  False                    False                True
# 4                  False                    False               False
#
#    Outlet_Size_Small  Outlet_Location_Type_Tier 2  \
# 0              False                        False
# 1              False                        False
# 2              False                        False
# 3              False                        False
# 4              False                        False
#
#    Outlet_Location_Type_Tier 3  Outlet_Type_Supermarket Type1  \
# 0                        False                           True
# 1                         True                          False
# 2                        False                           True
# 3                         True                          False
# 4                         True                           True
#
#    Outlet_Type_Supermarket Type2  Outlet_Type_Supermarket Type3
# 0                          False                          False
# 1                           True                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
#
# [5 rows x 28 columns]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\anaconda\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\anaconda\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\anaconda\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\anaconda\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\anaconda\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# Training data shape: (6818, 28)
# Testing data shape: (1705, 28)

# %%
from sklearn.linear_model import LinearRegression

# create model
lr = LinearRegression()

#train model
lr.fit(x_train, y_train)

print("Model training completed")
# Out:
# Model training completed

# %%
y_pred = lr.predict(x_test)

print(y_pred[:10])
# Out:
# [1353.22524774  765.30277011  817.5191853  4227.53298874 3281.11403439
#   575.46202873 4778.53611664 2037.56341795 1385.89703414 2774.2141172 ]

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test,y_pred))
r2 = r2_score(y_test, y_pred)

print("RMSE:",rmse)
print("R2 Score:",r2)
# Out:
# RMSE: 1068.4703615162775
# R2 Score: 0.5799700197361619

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)

rf.fit(x_train,y_train)

print("Random Forest model trained")
# Out:
# Random Forest model trained

# %%
rf_pred = rf.predict(x_test)

print(rf_pred[:10])
# Out:
# [ 791.250036  864.401482  840.679028 5067.310588 2195.302392  457.844028
#  5725.34736  1303.676348 1007.168976 2774.228808]

# %%
rmse_rf = np.sqrt(mean_squared_error(y_test, rf_pred))
r2_rf = r2_score(y_test, rf_pred)

print("Random Forest RMSE:",rmse_rf)
print("Random Forest R2:",r2_rf)
# Out:
# Random Forest RMSE: 1092.296901669416
# Random Forest R2: 0.561028086346157

# %%
import joblib
joblib.dump(lr,"../models/sales_prediction_model.pkl")
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    "Feature":x_train.columns,
    "Importance":lr.coef_
})
feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

feature_importance.head(10)
# Out:
#                             Feature   Importance
# 27    Outlet_Type_Supermarket Type3  3798.821753
# 25    Outlet_Type_Supermarket Type1  1533.207615
# 26    Outlet_Type_Supermarket Type2  1286.819256
# 17                Item_Type_Seafood   231.412846
# 7               Item_Type_Breakfast    67.245529
# 11  Item_Type_Fruits and Vegetables    46.972051
# 5          Item_Fat_Content_Regular    43.940770
# 8                  Item_Type_Canned    26.811593
# 20          Item_Type_Starchy Foods    24.790287
# 13     Item_Type_Health and Hygiene    16.660177

# %%
# !pip install matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(6,6))
#       4 plt.scatter(y_test,y_pred)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib) (1.3.3)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in c:\anaconda\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\anaconda\lib\site-packages (from matplotlib) (12.0.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 574.6 kB/s eta 0:00:14
#    -- ------------------------------------- 0.5/8.1 MB 574.6 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/8.1 MB 627.2 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.0/8.1 MB 659.5 kB/s eta 0:00:11
#    ------ --------------------------------- 1.3/8.1 MB 748.1 kB/s eta 0:00:10
#    ------- -------------------------------- 1.6/8.1 MB 823.7 kB/s eta 0:00:08
#    ------- -------------------------------- 1.6/8.1 MB 823.7 kB/s eta 0:00:08
#    --------- ------------------------------ 1.8/8.1 MB 846.0 kB/s eta 0:00:08
#    --------- ------------------------------ 1.8/8.1 MB 846.0 kB/s eta 0:00:08
#    ---------- ----------------------------- 2.1/8.1 MB 797.6 kB/s eta 0:00:08
#    ---------- ----------------------------- 2.1/8.1 MB 797.6 kB/s eta 0:00:08
#    ----------- ---------------------------- 2.4/8.1 MB 774.4 kB/s eta 0:00:08
#    ------------ --------------------------- 2.6/8.1 MB 781.5 kB/s eta 0:00:08
#    ------------ --------------------------- 2.6/8.1 MB 781.5 kB/s eta 0:00:08
#    -------------- ------------------------- 2.9/8.1 MB 756.5 kB/s eta 0:00:07
#    -------------- ------------------------- 2.9/8.1 MB 756.5 kB/s eta 0:00:07
#    --------------- ------------------------ 3.1/8.1 MB 769.0 kB/s eta 0:00:07
#    --------------- ------------------------ 3.1/8.1 MB 769.0 kB/s eta 0:00:07
#    --------------- ------------------------ 3.1/8.1 MB 769.0 kB/s eta 0:00:07
#    ---------------- ----------------------- 3.4/8.1 MB 701.1 kB/s eta 0:00:07
#    ---------------- ----------------------- 3.4/8.1 MB 701.1 kB/s eta 0:00:07
#    ---------------- ----------------------- 3.4/8.1 MB 701.1 kB/s eta 0:00:07
#    ---------------- ----------------------- 3.4/8.1 MB 701.1 kB/s eta 0:00:07
#    ------------------ --------------------- 3.7/8.1 MB 646.1 kB/s eta 0:00:07
#    ------------------ --------------------- 3.7/8.1 MB 646.1 kB/s eta 0:00:07
#    ------------------- -------------------- 3.9/8.1 MB 634.4 kB/s eta 0:00:07
#    -------------------- ------------------- 4.2/8.1 MB 658.3 kB/s eta 0:00:06
#    --------------------- ------------------ 4.5/8.1 MB 682.4 kB/s eta 0:00:06
#    ----------------------- ---------------- 4.7/8.1 MB 702.2 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.7/8.1 MB 702.2 kB/s eta 0:00:05
#    ------------------------ --------------- 5.0/8.1 MB 711.6 kB/s eta 0:00:05
#    ------------------------- -------------- 5.2/8.1 MB 712.3 kB/s eta 0:00:05
#    --------------------------- ------------ 5.5/8.1 MB 726.4 kB/s eta 0:00:04
#    ---------------------------- ----------- 5.8/8.1 MB 741.1 kB/s eta 0:00:04
#    ----------------------------- ---------- 6.0/8.1 MB 759.5 kB/s eta 0:00:03
#    ------------------------------ --------- 6.3/8.1 MB 779.9 kB/s eta 0:00:03
#    -------------------------------- ------- 6.6/8.1 MB 796.9 kB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 811.5 kB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 814.0 kB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 814.0 kB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 814.0 kB/s eta 0:00:02
#    ------------------------------------ --- 7.3/8.1 MB 783.7 kB/s eta 0:00:02
#    ------------------------------------ --- 7.3/8.1 MB 783.7 kB/s eta 0:00:02
#    ------------------------------------ --- 7.3/8.1 MB 783.7 kB/s eta 0:00:02
#    ------------------------------------ --- 7.3/8.1 MB 783.7 kB/s eta 0:00:02
#    ------------------------------------- -- 7.6/8.1 MB 751.2 kB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 751.2 kB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 739.9 kB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 739.9 kB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 737.4 kB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 729.3 kB/s  0:00:11
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.2 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 951.7 kB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 951.7 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 846.3 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 846.3 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 846.3 kB/s eta 0:00:02
#    -------------------------- ------------- 1.6/2.3 MB 766.0 kB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 786.1 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 799.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 799.4 kB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 795.5 kB/s  0:00:02
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, matplotlib
#
#    ---------------------------------------- 0/5 [pyparsing]
#    ---------------------------------------- 0/5 [pyparsing]
#    ---------------------------------------- 0/5 [pyparsing]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    ---------------- ----------------------- 2/5 [fonttools]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    ---------------------------------------- 5/5 [matplotlib]
#
# Successfully installed cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pyparsing-3.3.2
